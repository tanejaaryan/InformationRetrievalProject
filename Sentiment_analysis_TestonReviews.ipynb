# %% [markdown]
# # 1. Install dependencies

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.0 MB 7.9 MB/s
#      |████████████████████████████████| 77 kB 6.8 MB/s
#      |████████████████████████████████| 6.6 MB 57.3 MB/s
#      |████████████████████████████████| 596 kB 50.3 MB/s
#      |████████████████████████████████| 895 kB 37.9 MB/s

# %%
string = """I genuinely think it’s a good course to take if it’s a field of interest. It genuinely requires effort but I found Anoop Sir to be very accommodating and understanding. The biggest plus of the course is that sir kept the expectation and assignments according to the student’s performance. He actually reduced his expectations when he realized the students might not be able to handle that much work. I feel that the course has a lot of practical learning and doesn’t harp on unnecessary theory. The grading is very reasonable. You can get a 9 if you have put good efforts. Having said that, the course does require a lot of effort, especially in the later assignments. I remember sitting in the design labs for 12 hours on stretch and spending even entire days there. 
Sir gives amazing feedback, which is another plus point. I think if you’re willing to make the effort, the course is a good investment since you get to learn good skills."""

string2 = """FMRP is relatively very easy. You will learn much more in practical work rather than what u would learn in theory. Theory is all about mugging up. Memorize everything, each and every line. Practical work is fun, full of creativity, one would love doing the practical work. It's a bit time consuming.Grading is easy and u will get more than what u deserve."""

# %% [markdown]
# # 2. Run sentiment analysis predictions by using Pipeline

# %%
# Using pipeline class to make predictions from models available in the Hub in an easy way 
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")
data = [string, string2]
sentiment_pipeline(data)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# [{'label': 'POSITIVE', 'score': 0.9985647797584534},
#  {'label': 'POSITIVE', 'score': 0.9891034364700317}]

# %% [markdown]
# # 3. Use a specific sentiment analysis model available on the Hub by specifying its name

# %%
# Using a specific model for sentiment analysis
specific_model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
specific_model(data)
# Out:
# Downloading:   0%|          | 0.00/987 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/890 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/515M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/824k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Please install emoji: pip3 install emoji
# [{'label': 'POS', 'score': 0.9903131723403931},
#  {'label': 'NEG', 'score': 0.9797351360321045}]
